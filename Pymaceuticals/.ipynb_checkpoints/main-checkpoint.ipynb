# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
mouse_drug_data_to_load = "mouse_drug_data.csv"
clinical_trial_data_to_load = "clinicaltrial_data.csv"

# Read the Mouse and Drug Data and the Clinical Trial Data
Mouse_df=pd.read_csv(mouse_drug_data_to_load)
Trial_df=pd.read_csv(clinical_trial_data_to_load)

Mouse_df.head()
# Out:
#   Mouse ID      Drug
# 0     f234  Stelasyn
# 1     x402  Stelasyn
# 2     a492  Stelasyn
# 3     w540  Stelasyn
# 4     v764  Stelasyn

# %%
Trial_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     b128          0                45.0                 0
# 1     f932          0                45.0                 0
# 2     g107          0                45.0                 0
# 3     a457          0                45.0                 0
# 4     c819          0                45.0                 0

# %%
# Combine the data into a single dataset
combined_df = pd.merge(Trial_df, Mouse_df,how='outer', on="Mouse ID")

# %%
# Display the data table for preview
combined_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites       Drug
# 0     b128          0           45.000000                 0  Capomulin
# 1     b128          5           45.651331                 0  Capomulin
# 2     b128         10           43.270852                 0  Capomulin
# 3     b128         15           43.784893                 0  Capomulin
# 4     b128         20           42.731552                 0  Capomulin

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 
mean_tv = combined_df.groupby(["Drug","Timepoint"]).mean()
mean_tv.reset_index(level = None, inplace = True)

# Convert toDataFrame
mean_df = pd.DataFrame(mean_tv)

# Preview DataFrame 
mean_df.head()
# Out:
#         Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0  Capomulin          0           45.000000          0.000000
# 1  Capomulin          5           44.266086          0.160000
# 2  Capomulin         10           43.084291          0.320000
# 3  Capomulin         15           42.064317          0.375000
# 4  Capomulin         20           40.716325          0.652174

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
combined_ste = combined_df.groupby(["Drug","Timepoint"]).sem()
combined_ste.reset_index(level = None, inplace = True)

# Convert to DataFrame
combined_ste_df = pd.DataFrame(combined_ste)

# Preview DataFrame 
combined_ste_df.head()
# Out:
#         Drug  Timepoint  Metastatic Sites  Mouse ID  Tumor Volume (mm3)
# 0  Capomulin          0          0.000000       NaN            0.000000
# 1  Capomulin          5          0.074833       NaN            0.448593
# 2  Capomulin         10          0.125433       NaN            0.702684
# 3  Capomulin         15          0.132048       NaN            0.838617
# 4  Capomulin         20          0.161621       NaN            0.909731

# %%
# Minor Data Munging to Re-Format the Data Frames
reformatsem_df= combined_ste_df.pivot(index ="Timepoint", columns = 'Drug', values = "Tumor Volume (mm3)")
reformatsem_df.reset_index(level = None, inplace = True)

#Preview the formatted table
reformatsem_df.head()
# Out:
# Drug  Timepoint  Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# 0             0   0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 1             5   0.448593  0.164505   0.235102  0.264819  0.202385  0.218091
# 2            10   0.702684  0.236144   0.282346  0.357421  0.319415  0.402064
# 3            15   0.838617  0.332053   0.357705  0.580268  0.444378  0.614461
# 4            20   0.909731  0.359482   0.476210  0.726484  0.595260  0.839609
#
# Drug  Propriva  Ramicane  Stelasyn  Zoniferol
# 0     0.000000  0.000000  0.000000   0.000000
# 1     0.231708  0.482955  0.239862   0.188950
# 2     0.376195  0.720225  0.433678   0.263949
# 3     0.466109  0.770432  0.493261   0.370544
# 4     0.555181  0.786199  0.621889   0.533182

# %%
finalsem_df = reformatsem_df[["Timepoint","Capomulin", "Infubinol", "Ketapril", "Placebo"]]
# Out:
# Drug  Timepoint  Capomulin  Infubinol  Ketapril   Placebo
# 0             0   0.000000   0.000000  0.000000  0.000000
# 1             5   0.448593   0.235102  0.264819  0.218091
# 2            10   0.702684   0.282346  0.357421  0.402064
# 3            15   0.838617   0.357705  0.580268  0.614461
# 4            20   0.909731   0.476210  0.726484  0.839609

# %%
# Minor Data Munging to Re-Format the Data Frames
reformatm_df= mean_df.pivot(index ="Timepoint", columns = 'Drug', values = "Tumor Volume (mm3)")
reformatm_df.reset_index(level = None, inplace = True)

#Preview the formatted table
reformatm_df.head()
# Out:
# Drug  Timepoint  Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol  \
# 0             0  45.000000  45.000000  45.000000  45.000000  45.000000
# 1             5  44.266086  46.503051  47.062001  47.389175  46.796098
# 2            10  43.084291  48.285125  49.403909  49.582269  48.694210
# 3            15  42.064317  50.094055  51.296397  52.399974  50.933018
# 4            20  40.716325  52.157049  53.197691  54.920935  53.644087
#
# Drug    Placebo   Propriva   Ramicane   Stelasyn  Zoniferol
# 0     45.000000  45.000000  45.000000  45.000000  45.000000
# 1     47.125589  47.248967  43.944859  47.527452  46.851818
# 2     49.423329  49.101541  42.531957  49.463844  48.689881
# 3     51.359742  51.067318  41.495061  51.529409  50.779059
# 4     54.364417  53.346737  40.238325  54.067395  53.170334

# %%
finaltr_df = reformatm_df[["Timepoint","Capomulin", "Infubinol", "Ketapril", "Placebo"]]
finaltr_df.head()
# Out:
# Drug  Timepoint  Capomulin  Infubinol   Ketapril    Placebo
# 0             0  45.000000  45.000000  45.000000  45.000000
# 1             5  44.266086  47.062001  47.389175  47.125589
# 2            10  43.084291  49.403909  49.582269  49.423329
# 3            15  42.064317  51.296397  52.399974  51.359742
# 4            20  40.716325  53.197691  54.920935  54.364417

# %%
plt.figure(figsize = (10, 5))

X=finaltr_df['Timepoint']
Y1=finaltr_df['Capomulin']
Y2=finaltr_df['Infubinol']
Y3=finaltr_df['Ketapril']
Y4=finaltr_df['Placebo']
Y_error1=finalsem_df['Capomulin']
Y_error2=finalsem_df['Infubinol']
Y_error3=finalsem_df['Ketapril']
Y_error4=finalsem_df['Placebo']

Capomulin=plt.errorbar(x=X, y=Y1, yerr=Y_error1, linestyle="--", fmt='o', label='Capomulin')
Infubinol=plt.errorbar(x=X, y=Y2, yerr=Y_error2, linestyle="--", fmt='o', label='Infubinol')
Ketapril=plt.errorbar(x=X, y=Y3, yerr=Y_error3, linestyle="--", fmt='o', label='Ketapril')
Placebo=plt.errorbar(x=X, y=Y4, yerr=Y_error4, linestyle="--", fmt='o', label='Placebo')

plt.ylabel('Tumor Volume(mm3)')
plt.xlabel('Time (Days)')
plt.title('Tumor Response to Treatment')
plt.grid()
plt.legend(loc='upper left')       
plt.show()

# %% [markdown]
# ![Tumor Response to Treatment](../Images/treatment.png)

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store the Mean Met. Site Data Grouped by Drug and Timepoint 
mean_met = combined_df.groupby(["Drug","Timepoint"]).mean()
mean_met.reset_index(level = None, inplace = True)

# Convert toDataFrame
mean_met_df = pd.DataFrame(mean_met)

# Preview DataFrame 
mean_met_df.head()
# Out:
#         Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0  Capomulin          0           45.000000          0.000000
# 1  Capomulin          5           44.266086          0.160000
# 2  Capomulin         10           43.084291          0.320000
# 3  Capomulin         15           42.064317          0.375000
# 4  Capomulin         20           40.716325          0.652174

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 
combined_metsem = combined_df.groupby(["Drug","Timepoint"]).sem()
combined_metsem.reset_index(level = None, inplace = True)

# Convert to DataFrame
combined_metsem_df = pd.DataFrame(combined_metsem)

# Preview DataFrame 
combined_metsem_df.head()
# Out:
#         Drug  Timepoint  Metastatic Sites  Mouse ID  Tumor Volume (mm3)
# 0  Capomulin          0          0.000000       NaN            0.000000
# 1  Capomulin          5          0.074833       NaN            0.448593
# 2  Capomulin         10          0.125433       NaN            0.702684
# 3  Capomulin         15          0.132048       NaN            0.838617
# 4  Capomulin         20          0.161621       NaN            0.909731

# %%
# Minor Data Munging to Re-Format the Data Frames
reformatmetsem_df= combined_metsem_df.pivot(index ="Timepoint", columns = 'Drug', values = "Metastatic Sites")
reformatmetsem_df.reset_index(level = None, inplace = True)

#Preview the formatted table
reformatmetsem_df.head()
# Out:
# Drug  Timepoint  Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# 0             0   0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 1             5   0.074833  0.108588   0.091652  0.098100  0.093618  0.100947
# 2            10   0.125433  0.152177   0.159364  0.142018  0.163577  0.115261
# 3            15   0.132048  0.180625   0.194015  0.191381  0.158651  0.190221
# 4            20   0.161621  0.241034   0.234801  0.236680  0.181731  0.234064
#
# Drug  Propriva  Ramicane  Stelasyn  Zoniferol
# 0     0.000000  0.000000  0.000000   0.000000
# 1     0.095219  0.066332  0.087178   0.077709
# 2     0.105690  0.090289  0.123672   0.109109
# 3     0.136377  0.115261  0.153439   0.111677
# 4     0.171499  0.119430  0.200905   0.166378

# %%
finalmetsem_df = reformatmetsem_df[["Timepoint","Capomulin", "Infubinol", "Ketapril", "Placebo"]]
finalmetsem_df.head()
# Out:
# Drug  Timepoint  Capomulin  Infubinol  Ketapril   Placebo
# 0             0   0.000000   0.000000  0.000000  0.000000
# 1             5   0.074833   0.091652  0.098100  0.100947
# 2            10   0.125433   0.159364  0.142018  0.115261
# 3            15   0.132048   0.194015  0.191381  0.190221
# 4            20   0.161621   0.234801  0.236680  0.234064

# %%
# Minor Data Munging to Re-Format the Data Frames
reformatmean_met_df= mean_met_df.pivot(index ="Timepoint", columns = 'Drug', values = "Metastatic Sites")
reformatmean_met_df.reset_index(level = None, inplace = True)

#Preview the formatted table
reformatmean_met_df.head()
# Out:
# Drug  Timepoint  Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# 0             0   0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 1             5   0.160000  0.380952   0.280000  0.304348  0.260870  0.375000
# 2            10   0.320000  0.600000   0.666667  0.590909  0.523810  0.833333
# 3            15   0.375000  0.789474   0.904762  0.842105  0.857143  1.250000
# 4            20   0.652174  1.111111   1.050000  1.210526  1.150000  1.526316
#
# Drug  Propriva  Ramicane  Stelasyn  Zoniferol
# 0     0.000000  0.000000  0.000000   0.000000
# 1     0.320000  0.120000  0.240000   0.166667
# 2     0.565217  0.250000  0.478261   0.500000
# 3     0.764706  0.333333  0.782609   0.809524
# 4     1.000000  0.347826  0.952381   1.294118

# %%
finalmean_met_df = reformatmean_met_df[["Timepoint","Capomulin", "Infubinol", "Ketapril", "Placebo"]]
finalmean_met_df.head()
# Out:
# Drug  Timepoint  Capomulin  Infubinol  Ketapril   Placebo
# 0             0   0.000000   0.000000  0.000000  0.000000
# 1             5   0.160000   0.280000  0.304348  0.375000
# 2            10   0.320000   0.666667  0.590909  0.833333
# 3            15   0.375000   0.904762  0.842105  1.250000
# 4            20   0.652174   1.050000  1.210526  1.526316

# %%
plt.figure(figsize = (10, 5))

X=finalmean_met_df['Timepoint']
Y1=finalmean_met_df['Capomulin']
Y2=finalmean_met_df['Infubinol']
Y3=finalmean_met_df['Ketapril']
Y4=finalmean_met_df['Placebo']
Y_error1=finalmetsem_df['Capomulin']
Y_error2=finalmetsem_df['Infubinol']
Y_error3=finalmetsem_df['Ketapril']
Y_error4=finalmetsem_df['Placebo']

Capomulin=plt.errorbar(x=X, y=Y1, yerr=Y_error1, linestyle="--", fmt='o', label='Capomulin')
Infubinol=plt.errorbar(x=X, y=Y2, yerr=Y_error2, linestyle="--", fmt='o', label='Infubinol')
Ketapril=plt.errorbar(x=X, y=Y3, yerr=Y_error3, linestyle="--", fmt='o', label='Ketapril')
Placebo=plt.errorbar(x=X, y=Y4, yerr=Y_error4, linestyle="--", fmt='o', label='Placebo')

plt.ylabel('Met. Sites')
plt.xlabel('Treatment Duration (Days)')
plt.title('Metastatic Spread During Treatment')
plt.grid()
plt.legend(loc='upper left')       
plt.show()

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/spread.png)

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)
mice_count=combined_df.groupby(["Drug","Timepoint"]).count()

# Convert to DataFrame
mice_count_df=pd.DataFrame(mice_count["Mouse ID"])
mice_count_df.reset_index(inplace=True)

#Display dataframe
mice_count_df.head()
# Out:
#         Drug  Timepoint  Mouse ID
# 0  Capomulin          0        25
# 1  Capomulin          5        25
# 2  Capomulin         10        25
# 3  Capomulin         15        24
# 4  Capomulin         20        23

# %%
# Minor Data Munging to Re-Format the Data Frames
reformatmice_count_df= mice_count_df.pivot(index ="Timepoint", columns = 'Drug', values = "Mouse ID")
reformatmice_count_df.reset_index(level = None, inplace = True)

#Preview the formatted table
reformatmice_count_df.head()
# Out:
# Drug  Timepoint  Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# 0             0         25        25         25        25        25       25
# 1             5         25        21         25        23        23       24
# 2            10         25        20         21        22        21       24
# 3            15         24        19         21        19        21       20
# 4            20         23        18         20        19        20       19
#
# Drug  Propriva  Ramicane  Stelasyn  Zoniferol
# 0           26        25        26         25
# 1           25        25        25         24
# 2           23        24        23         22
# 3           17        24        23         21
# 4           17        23        21         17

# %%
reformatmice_count_df = reformatmice_count_df[["Timepoint","Capomulin", "Infubinol", "Ketapril", "Placebo"]]
reformatmice_count_df.head()
# Out:
# Drug  Timepoint  Capomulin  Infubinol  Ketapril  Placebo
# 0             0         25         25        25       25
# 1             5         25         25        23       24
# 2            10         25         21        22       24
# 3            15         24         21        19       20
# 4            20         23         20        19       19

# %%
final_mice_count_df = reformatmice_count_df.astype(float)
final_mice_count_df["Capomulin_Survival_Rate"]=final_mice_count_df["Capomulin"]/final_mice_count_df["Capomulin"].iloc[0] * 100
final_mice_count_df["Infubinol_Survival_Rate"]=final_mice_count_df["Infubinol"]/final_mice_count_df["Infubinol"].iloc[0] * 100
final_mice_count_df["Ketapril_Survival_Rate"]=final_mice_count_df["Ketapril"]/final_mice_count_df["Ketapril"].iloc[0] * 100
final_mice_count_df["Placebo_Survival_Rate"]=final_mice_count_df["Placebo"]/final_mice_count_df["Placebo"].iloc[0] * 100
final_mice_count_df
# Out:
# Drug  Timepoint  Capomulin  Infubinol  Ketapril  Placebo  \
# 0           0.0       25.0       25.0      25.0     25.0
# 1           5.0       25.0       25.0      23.0     24.0
# 2          10.0       25.0       21.0      22.0     24.0
# 3          15.0       24.0       21.0      19.0     20.0
# 4          20.0       23.0       20.0      19.0     19.0
# 5          25.0       22.0       18.0      19.0     17.0
# 6          30.0       22.0       17.0      18.0     15.0
# 7          35.0       22.0       12.0      17.0     14.0
# 8          40.0       21.0       10.0      15.0     12.0
# 9          45.0       21.0        9.0      11.0     11.0
#
# Drug  Capomulin_Survival_Rate  Infubinol_Survival_Rate  \
# 0                       100.0                    100.0
# 1                       100.0                    100.0
# 2                       100.0                     84.0
# 3                        96.0                     84.0
# 4                        92.0                     80.0
# ...

# %%
plt.figure(figsize = (10, 5))

X=final_mice_count_df['Timepoint']
Y1=final_mice_count_df["Capomulin_Survival_Rate"]
Y2=final_mice_count_df["Infubinol_Survival_Rate"]
Y3=final_mice_count_df["Ketapril_Survival_Rate"]
Y4=final_mice_count_df["Placebo_Survival_Rate"]

Capomulin=plt.errorbar(x=X, y=Y1, linestyle="--", fmt='o', label='Capomulin')
Infubinol=plt.errorbar(x=X, y=Y2, linestyle="--", fmt='o', label='Infubinol')
Ketapril=plt.errorbar(x=X, y=Y3, linestyle="--", fmt='o', label='Ketapril')
Placebo=plt.errorbar(x=X, y=Y4, linestyle="--", fmt='o', label='Placebo')

plt.ylabel('Survival During Treatment')
plt.xlabel('Treatment Duration (Days)')
plt.title('Survival Rate (%)')
plt.grid()
plt.legend(loc='upper left')       
plt.show()

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/survival.png)

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug

# Display the data to confirm

# %%
# Store all Relevant Percent Changes into a Tuple


# Splice the data between passing and failing drugs


# Orient widths. Add labels, tick marks, etc. 


# Use functions to label the percentages of changes


# Call functions to implement the function calls


# Save the Figure


# Show the Figure
fig.show()

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/change.png)
